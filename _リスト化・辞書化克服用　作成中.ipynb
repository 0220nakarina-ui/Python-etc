# %% [markdown]
# <a href="https://colab.research.google.com/github/0220nakarina-ui/Python-etc/blob/main/_%E3%83%AA%E3%82%B9%E3%83%88%E5%8C%96%E3%83%BB%E8%BE%9E%E6%9B%B8%E5%8C%96%E5%85%8B%E6%9C%8D%E7%94%A8%E3%80%80%E4%BD%9C%E6%88%90%E4%B8%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#練習
#リスト化・辞書化克服用
#花束を作ろう
#使いたい花→紫陽花(青)・紫リンドウ・紫トルコキキョウ・レモンリーフ
list = [
       {"flower":"紫陽花(青)","category":"花","place":"1000"},
       {"flower":"紫リンドウ","category":"花","place":"250"},
       {"flower":"紫トルコキキョウ","category":"花","place":"600"},
       {"flower":"レモンリーフ","category":"葉","place":"300"},
]

#紫陽花(青)・紫リンドウ・紫トルコキキョウ・レモンリーフで合計\5000以内で作りたい
#紫陽花(青)メインという内容のオーダーが入ったよ、作ろう

budget = 5000  #\5000以内
n = 5          #n = 花の合計数・自由に変えられる

bouquet = []   #花がまだ無いよ
total = 0      #まだ0円

#紫陽花(青)がメイン
for _ in range (n):
  if total + list [0]["place"]  <= budget:
    bouquet.append (list[0]["flower"])
    total += flower_list [0]["place"]

#他の花も入れよう
